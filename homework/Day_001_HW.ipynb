# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %% [markdown]
# 作業1:
# 於Kaggle上找了Competitions, 其中Google Landmark Recognition 2019當作本題討論之對象
# 1. 你選的這組資料為何重要?
# A: 每個人一生中都會遊歷許多地方，其中某些地方可能某些原因只能去一次，但同時也擁有許多美好的回憶，將來欲與人分享時，印象模糊只能依靠昔日的照片尋找線索，此時Machine Learning的用處即可發揮，幫助我們了解昔日的自己，亦可了解別人的過去，猶如身歷其境。
#
# 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)?
# A: 資料的蒐集可以透過google圖片來蒐集相關圖片檔
#
# 3. 蒐集而來的資料型態為何?
# A: 圖片蒐集之型態為圖像的形式
#
# 4. 這組資料想解決的問題如何評估?
# A: 此競賽想解決的問題主要就是能夠自動辨認照片中之風景地為何，解決此問題前需先得到能夠涵蓋各風景之相關資料與圖片，若非，則得到準確率有待商榷

# %% [markdown]
# 作業2:
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
# 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
# A: 提升業績最終的目的是要增加營收，因此可以分為兩部分討論：降低成本、業績增加，其中降低成本為考量油資的部分，確保油資不會因為長途的客源而利潤降低，且收費應包含此段時間無法載短途而少收之平均利潤；而業績增加淨營收可以增加。假設則有以下幾點：油價不變、乘客不會殺價、不塞車、路段皆為平地等。
#
# 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
# A: 每天的油價會浮動，可以從公開公告油價處爬取。每位司機可以先行紀錄並計算載每位乘客之時間及營收，解析何種乘客之性價比較高，主力開發該客源，開發方式可透過解析與統計該客源之特性，如：何種時段、常載取之路段等等，最後再統計這些改變後之營收以調整未來方針。
#
# 3. 蒐集而來的資料型態為何
# A: 蒐集得知之資料可以表格的形式存於資料庫中
#
# 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
# A: 核心問題主要討論淨利潤的提升，可透過查看年或月營收扣除成本後比對總額得知；假設的部分則可利用平均值為方針來模擬計算成本的部分

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_absolute_error(y, yp):
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

# %%
def mean_squared_error(y, yp):
    mse = MSE = sum(abs(y - yp)**2) / len(y)
    return mse

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 226.658
# The Mean absolute error is 12.329
